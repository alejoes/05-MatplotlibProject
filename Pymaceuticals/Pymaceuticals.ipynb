# %%
# %matplotlib notebook
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
clinical=pd.read_csv("/Users/marian/Dropbox/ALejandro/ColumbiaBC/Assignments/05-Matplotlib/Pymaceuticals/data/clinicaltrial_data.csv")
mouse=pd.read_csv("/Users/marian/Dropbox/ALejandro/ColumbiaBC/Assignments/05-Matplotlib/Pymaceuticals/data/mouse_drug_data.csv")

# %%
#clinical.info()

# %%
clinical_copy=clinical.copy()
#clinical_copy.dropna(how="any")
#clinical_copy.info()

# %%
clinical=clinical.rename(columns={"Mouse ID":"Mouse_ID"})
clinical.head()
# Out:
#   Mouse_ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
#mouse.info()

# %%
mouse_copy=mouse.copy()
#mouse_copy.dropna(how="any")
#mouse_copy.info()

# %%
mouse=mouse.rename(columns={"Mouse ID":"Mouse_ID"})
mouse.head(10)
# Out:
#   Mouse_ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn
# 5     o848  Stelasyn
# 6     z314  Stelasyn
# 7     g989  Stelasyn
# 8     m269  Stelasyn
# 9     a963  Stelasyn

# %%
superT=pd.merge(clinical,mouse,on="Mouse_ID")
superT.Drug.unique()
# Out:
# array(['Capomulin', 'Ketapril', 'Naftisol', 'Infubinol', 'Stelasyn',
#        'Ramicane', 'Propriva', 'Zoniferol', 'Placebo', 'Ceftamin'],
#       dtype=object)

# %%
#PLACEBO
dm = sns.light_palette("red",as_cmap=True,reverse=False)
plc=superT[superT.Drug=="Placebo"]
    #Tumor Volume
plc_p=(plc.pivot(index="Timepoint",columns="Mouse_ID",values="Tumor Volume (mm3)")).reset_index()
pp=plc_p[["a262","a897","c282","c757","c766","e227","o795","q787","t718","x773","y478","i477","i669","j235","l872",
            "n763","o302","q582","r850","s152","s166","t994","v409","v989","w167"]]
p=pp.style.background_gradient(cmap=dm)
        #Average Tumor growth
AvP=plc_p.drop(["Timepoint"],axis=1)
AvPP=AvP.mean(axis=1).reset_index()
        #Standard Deviation
SdP=AvP.std(axis=1).reset_index()
    #Mtastatic Sites
plc_m=(plc.pivot(index="Timepoint",columns="Mouse_ID",values="Metastatic Sites")).reset_index()
pm=plc_m[["a262","a897","c282","c757","c766","e227","o795","q787","t718","x773","y478","i477","i669","j235","l872",
            "n763","o302","q582","r850","s152","s166","t994","v409","v989","w167"]]
pmm=pm.style.background_gradient(cmap=dm)#, subset=['a262','a897'......])

#CAPOMULIN
gm = sns.light_palette("green",as_cmap=True,reverse=False)
capo=superT[superT.Drug=="Capomulin"]
    #Tumor Volume
capo_p=capo.pivot(index="Timepoint",columns="Mouse_ID",values="Tumor Volume (mm3)").reset_index()
cp=capo_p[["b128","b742","g288","g316","i557","i738","j119","l509","l897","m601","m957","r554",
        "r944","s185","s710","t565","u364","v923","w914","x401","y793","f966","j246","r157","w150"]]
c=cp.style.background_gradient(cmap=gm)#, subset=['b128','b742',.....])
        #Average Tumor growth
AvC=capo_p.drop(["Timepoint"],axis=1)
AvCC=AvC.mean(axis=1).reset_index()
        #Standard Deviation
SdC=AvC.std(axis=1).reset_index()
    #Metastatic Sites
capo_m=capo.pivot(index="Timepoint",columns="Mouse_ID",values="Metastatic Sites").reset_index()
cm=capo_m[["b128","b742","g288","g316","i557","i738","j119","l509","l897","m601","m957","r554",
        "r944","s185","s710","t565","u364","v923","w914","x401","y793","f966","j246","r157","w150"]]
cmm=cm.style.background_gradient(cmap=gm)

#KETAPRIL
bm = sns.light_palette("blue",as_cmap=True,reverse=False)
keta=superT[superT.Drug=="Ketapril"]
    #Tumor Volume
keta_p=keta.pivot(index="Timepoint",columns="Mouse_ID",values="Tumor Volume (mm3)").reset_index()
kp=keta_p[["c832","g497","h246","k382","m550","m650","o331","p189","u327","w422","y260","v603","v289","q119","o973",
        "n923","l264","h428","g107","f932","f278","d474","c819","c580","a457"]]
b=kp.style.background_gradient(cmap=bm)
        #Average Tumor growth
AvK=keta_p.drop(["Timepoint"],axis=1)
AvKK=AvK.mean(axis=1).reset_index()        
        #Standard Deviation
SdK=AvK.std(axis=1).reset_index()
    #Metastatic Sites
keta_m=keta.pivot(index="Timepoint",columns="Mouse_ID",values="Metastatic Sites").reset_index()
km=keta_m[["c832","g497","h246","k382","m550","m650","o331","p189","u327","w422","y260","v603","v289","q119","o973",
        "n923","l264","h428","g107","f932","f278","d474","c819","c580","a457"]]
bm=km.style.background_gradient(cmap=bm)#, subset=['a457','c580',....])

#INFUBINOL
ym = sns.light_palette("yellow",as_cmap=True,reverse=False)
infu=superT[superT.Drug=="Infubinol"]
    #Tumor Volume
infu_p=infu.pivot(index="Timepoint",columns="Mouse_ID",values="Tumor Volume (mm3)").reset_index()
ip=infu_p[["a203","a251","a685","c139","e476","f345","k483","y163","z581","a577","c326","c895","i386","k804","m756",
        "n671","o809","o813","q132","s121","v339","v719","v766","w193","w584"]]
y=ip.style.background_gradient(cmap=ym)
        #Average Tumor growth
AvI=infu_p.drop(["Timepoint"],axis=1)
AvII=AvI.mean(axis=1).reset_index()
        #Standard Deviation
SdI=AvI.std(axis=1).reset_index()
    #Metastatic Sites
infu_m=infu.pivot(index="Timepoint",columns="Mouse_ID",values="Metastatic Sites").reset_index()
im=infu_m[["a203","a251","a685","c139","e476","f345","k483","y163","z581","a577","c326","c895","i386","k804","m756",
        "n671","o809","o813","q132","s121","v339","v719","v766","w193","w584"]]
ym=im.style.background_gradient(cmap=ym)

# %% [markdown]
# # PLACEBO EFFECT ON TUMOR GROWTH

# %%
p
# Out:
# <style  type="text/css" >
#     #T_4a8db452_bd46_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_4a8db452_bd46_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_4a8db452_bd46_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_4a8db452_bd46_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_4a8db452_bd46_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_4a8db452_bd46_11e9_b557_6030d4619be4row0_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_4a8db452_bd46_11e9_b557_6030d4619be4row0_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
# ...

# %%
markex=[".",",","v","<","^",">","o","1","2","3","4","8","s","P","p","*","h","H","x","X","+","D","d","|","_"]
colox=["b","g","k","r","m","y","c","b","g","k","r","m","y","c","b","g","k","r","m","y","c","k","b","g","y"]
i=1
#fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(3, 3))
ax1=plc_p.plot(kind="scatter",x="Timepoint", y='a262', color='r',figsize=(5,5)) 
bx1=capo_p.plot(kind="scatter",x="Timepoint", y='b128', color='r',figsize=(5,5))
for valuex in range(2,len(plc_p.columns)):
    plc_p.plot(kind="scatter",x=plc_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=ax1)
    capo_p.plot(kind="scatter",x=capo_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=bx1)
    i=i+1

# %% [markdown]
# # CAPOMULIN EFFECT ON TUMOR GROWTH

# %%
c
# Out:
# <style  type="text/css" >
#     #T_4bad6d96_bd46_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #138a13;
#             color:  #000000;
#         }    #T_4bad6d96_bd46_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4bad6d96_bd46_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_4bad6d96_bd46_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #3ea23e;
#             color:  #000000;
#         }    #T_4bad6d96_bd46_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_4bad6d96_bd46_11e9_b557_6030d4619be4row0_col5 {
#             background-color:  #0d870d;
#             color:  #f1f1f1;
#         }    #T_4bad6d96_bd46_11e9_b557_6030d4619be4row0_col6 {
#             background-color:  #48a848;
#             color:  #000000;
# ...

# %% [markdown]
# # KETAPRIL EFFECT ON TUMOR GROWTH

# %%
b
# Out:
# <style  type="text/css" >
#     #T_4c733508_bd46_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_4c733508_bd46_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_4c733508_bd46_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_4c733508_bd46_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_4c733508_bd46_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_4c733508_bd46_11e9_b557_6030d4619be4row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_4c733508_bd46_11e9_b557_6030d4619be4row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
# ...

# %%
i=1
cx1=keta_p.plot(kind="scatter",x="Timepoint", y='a457', color='r',figsize=(5,5))
dx1=infu_p.plot(kind="scatter",x="Timepoint", y='z581', color='r',figsize=(5,5)) 
for valuex in range(2,len(keta_p.columns)):
    keta_p.plot(kind="scatter",x=keta_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=cx1)
    infu_p.plot(kind="scatter",x=infu_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=dx1)
    i=i+1

# %% [markdown]
# # INFUBINOL EFFECT ON TUMOR'S GROWTH

# %%
y
# Out:
# <style  type="text/css" >
#     #T_4d659f28_bd46_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_4d659f28_bd46_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_4d659f28_bd46_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_4d659f28_bd46_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_4d659f28_bd46_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_4d659f28_bd46_11e9_b557_6030d4619be4row0_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_4d659f28_bd46_11e9_b557_6030d4619be4row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
# ...

# %%
days=capo_p["Timepoint"].reset_index()
AvT=pd.merge(days,AvPP,on="index")
AvT=AvT.rename(columns={0:"Placebo"})
AvT=pd.merge(AvT,AvCC,on="index")
AvT=AvT.rename(columns={0:"Capomulin"})
AvT=pd.merge(AvT,AvKK,on="index")
AvT=AvT.rename(columns={0:"Ketapril"})
AvT=pd.merge(AvT,AvII,on="index")
AvT=AvT.rename(columns={0:"Infubinol","Timepoint":"Time (days)"})
AvT=AvT.drop(["index"],axis=1)
AvT
# Out:
#    Time (days)    Placebo  Capomulin   Ketapril  Infubinol
# 0            0  45.000000  45.000000  45.000000  45.000000
# 1            5  47.125589  44.266086  47.389175  47.062001
# 2           10  49.423329  43.084291  49.582269  49.403909
# 3           15  51.359742  42.064317  52.399974  51.296397
# 4           20  54.364417  40.716325  54.920935  53.197691
# 5           25  57.482574  39.939528  57.678982  55.715252
# 6           30  59.809063  38.769339  60.994507  58.299397
# 7           35  62.420615  37.816839  63.371686  60.742461
# 8           40  65.052675  36.958001  66.068580  63.162824
# 9           45  68.084082  36.236114  70.662958  65.755562

# %%
gl=AvT.plot(x="Time (days)", y="Placebo",linestyle="-.", color='r',marker="8",figsize=(6,6))
AvT.plot(x="Time (days)", y="Capomulin",linestyle="--", color='b',marker="^",ax=gl)
AvT.plot(x="Time (days)", y="Ketapril", color='k',marker="s",ax=gl)
AvT.plot(x="Time (days)", y="Infubinol", color='m',marker="4",ax=gl)
plt.ylabel("Tumor Volume (mm3)")
plt.title("Treatment effect on Tumor Growth")
# Out:
# Text(0.5, 1.0, 'Treatment effect on Tumor Growth')

# %%
superT[superT.Timepoint==45].count()
# Out:
# Mouse_ID              130
# Timepoint             130
# Tumor Volume (mm3)    130
# Metastatic Sites      130
# Drug                  130
# dtype: int64

# %% [markdown]
# # PLACEBO EFFECT ON METASTASIS

# %%
pmm
# Out:
# <style  type="text/css" >
#     #T_d26b0e6a_bd37_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d26b0e6a_bd37_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d26b0e6a_bd37_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d26b0e6a_bd37_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d26b0e6a_bd37_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d26b0e6a_bd37_11e9_b557_6030d4619be4row0_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d26b0e6a_bd37_11e9_b557_6030d4619be4row0_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
# ...

# %%
i=1
#fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(3, 3))
aax1=plc_m.plot(x="Timepoint",linestyle="-.", y='a262', color='r',figsize=(6,6),alpha=0.2) 
bbx1=capo_m.plot(x="Timepoint",linestyle="-.", y='b128', color='r',figsize=(6,6),alpha=0.2)
for valuex in range(2,len(plc_p.columns)):
    plc_m.plot(kind="scatter",x=plc_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=aax1)
    capo_m.plot(kind="scatter",x=capo_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=bbx1)
    i=i+1

# %% [markdown]
# # CAPOMULIN EFFECT ON METASTASIS

# %%
cmm
# Out:
# <style  type="text/css" >
#     #T_f41e440c_bd3a_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f41e440c_bd3a_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f41e440c_bd3a_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f41e440c_bd3a_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f41e440c_bd3a_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f41e440c_bd3a_11e9_b557_6030d4619be4row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f41e440c_bd3a_11e9_b557_6030d4619be4row0_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
# ...

# %% [markdown]
# # KETAPRIL EFFECT ON METASTASIS

# %%
bm
# Out:
# <style  type="text/css" >
#     #T_e52b1e78_bd3c_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e52b1e78_bd3c_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e52b1e78_bd3c_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e52b1e78_bd3c_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e52b1e78_bd3c_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #e5e5ff;
# ...

# %%
i=1
ccx1=keta_m.plot(x="Timepoint",linestyle="-.", y='k382', color='r',figsize=(6,6),alpha=0.2)
ddx1=infu_m.plot(x="Timepoint",linestyle="-.", y='z581', color='r',figsize=(6,6),alpha=0.2) 
for valuex in range(2,len(keta_p.columns)):
    keta_m.plot(kind="scatter",x=keta_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=ccx1)
    infu_m.plot(kind="scatter",x=infu_p.columns[0], y=valuex, color=colox[i],marker=markex[i],ax=ddx1)
    i=i+1

# %% [markdown]
# # INFUBINOL EFFECT ON METASTASIS

# %%
ym
# Out:
# <style  type="text/css" >
#     #T_e925c248_bd3d_11e9_b557_6030d4619be4row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_e925c248_bd3d_11e9_b557_6030d4619be4row0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_e925c248_bd3d_11e9_b557_6030d4619be4row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_e925c248_bd3d_11e9_b557_6030d4619be4row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_e925c248_bd3d_11e9_b557_6030d4619be4row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_e925c248_bd3d_11e9_b557_6030d4619be4row0_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_e925c248_bd3d_11e9_b557_6030d4619be4row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
# ...
