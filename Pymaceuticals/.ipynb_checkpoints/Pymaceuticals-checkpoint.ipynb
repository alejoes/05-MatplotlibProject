# %%
# %matplotlib notebook
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import sem
from matplotlib import figure

# %%
clinical=pd.read_csv("/Users/marian/Dropbox/ALejandro/ColumbiaBC/Assignments/05-Matplotlib/Pymaceuticals/data/clinicaltrial_data.csv")
mouse=pd.read_csv("/Users/marian/Dropbox/ALejandro/ColumbiaBC/Assignments/05-Matplotlib/Pymaceuticals/data/mouse_drug_data.csv")

# %%
#clinical.info()

# %%
clinical_copy=clinical.copy()
#clinical_copy.dropna(how="any")
#clinical_copy.info()

# %%
clinical=clinical.rename(columns={"Mouse ID":"Mouse_ID"})
clinical.head()
# Out:
#   Mouse_ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
#mouse.info()

# %%
mouse_copy=mouse.copy()
#mouse_copy.dropna(how="any")
#mouse_copy.info()

# %%
mouse=mouse.rename(columns={"Mouse ID":"Mouse_ID"})
mouse.head(10)
# Out:
#   Mouse_ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn
# 5     o848  Stelasyn
# 6     z314  Stelasyn
# 7     g989  Stelasyn
# 8     m269  Stelasyn
# 9     a963  Stelasyn

# %%
superT=pd.merge(clinical,mouse,on="Mouse_ID")
superT.Drug.unique()
# Out:
# array(['Capomulin', 'Ketapril', 'Naftisol', 'Infubinol', 'Stelasyn',
#        'Ramicane', 'Propriva', 'Zoniferol', 'Placebo', 'Ceftamin'],
#       dtype=object)

# %%
superT=superT.rename(columns={"Timepoint": "Time (days)"})
superT.head()
# Out:
#   Mouse_ID  Time (days)  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128            0           45.000000                 0  Capomulin
# 1     b128            5           45.651331                 0  Capomulin
# 2     b128           10           43.270852                 0  Capomulin
# 3     b128           15           43.784893                 0  Capomulin
# 4     b128           20           42.731552                 0  Capomulin

# %%
placeb=["a262","a897","c282","c757","c766","e227","o795","q787","t718","x773","y478","i477","i669","j235","l872",
            "n763","o302","q582","r850","s152","s166","t994","v409","v989","w167"]
capom=["b128","b742","g288","g316","i557","i738","j119","l509","l897","m601","m957","r554",
        "r944","s185","s710","t565","u364","v923","w914","x401","y793","f966","j246","r157","w150"]
ketap=["c832","g497","h246","k382","m550","m650","o331","p189","u327","w422","y260","v603","v289","q119","o973",
        "n923","l264","h428","g107","f932","f278","d474","c819","c580","a457"]
infu=["a203","a251","a685","c139","e476","f345","k483","y163","z581","a577","c326","c895","i386","k804","m756",
        "n671","o809","o813","q132","s121","v339","v719","v766","w193","w584"]

def data_d(superT,drug,grad_color,Variab,arrayx,a,b):
    dm = sns.light_palette(grad_color,as_cmap=True,reverse=False)
    data_drug=superT[superT.Drug==drug]
     #Tumor Volume
    data_drug_p=(data_drug.pivot(index="Time (days)",columns="Mouse_ID",values=Variab)).reset_index()
    data_sort=data_drug_p[arrayx]
    Data_Style=data_sort.style.background_gradient(cmap=dm)
         #Average Tumor growth & Standard Deviation    
    AvP=data_drug_p.drop(["Time (days)"],axis=1)  
    Stats=AvP.apply(pd.DataFrame.describe, axis=1)
    Stats["Std_Error"]=Stats["std"]/np.sqrt(AvP.shape[1])
    Stats=Stats.drop(["min","25%","50%","75%","max","std"],axis=1)
    days=data_drug_p["Time (days)"].tolist()
    Stats["Time (days)"]=days
    Stats=Stats.set_index("Time (days)")
    Stats=Stats.rename(columns={"mean":drug+" "+a,"Std_Error":drug+" "+b,"count":drug+" "+"(Alive Mice)"})
    return Stats,data_drug_p,Data_Style

SuperD_P=data_d(superT,"Placebo","red","Tumor Volume (mm3)",placeb,a="(Mean)",b="(StdE)")
SuperD_C=data_d(superT,"Capomulin","green","Tumor Volume (mm3)",capom,a="(Mean)",b="(StdE)")
SuperD_K=data_d(superT,"Ketapril","blue","Tumor Volume (mm3)",ketap,a="(Mean)",b="(StdE)")
SuperD_I=data_d(superT,"Infubinol","yellow","Tumor Volume (mm3)",infu,a="(Mean)",b="(StdE)")

SuperD_mP=data_d(superT,"Placebo","red","Metastatic Sites",placeb,a="(Mean)",b="(StdE)")
SuperD_mC=data_d(superT,"Capomulin","green","Metastatic Sites",capom,a="(Mean)",b="(StdE)")
SuperD_mK=data_d(superT,"Ketapril","blue","Metastatic Sites",ketap,a="(Mean)",b="(StdE)")
SuperD_mI=data_d(superT,"Infubinol","yellow","Metastatic Sites",infu,a="(Mean)",b="(StdE)")

# %% [markdown]
# # PLACEBO EFFECT ON TUMOR GROWTH

# %%
SuperD_P[2]
# Out:
# <style  type="text/css" >
#     #T_7c045ed0_c126_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_7c045ed0_c126_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_7c045ed0_c126_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_7c045ed0_c126_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_7c045ed0_c126_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_7c045ed0_c126_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_7c045ed0_c126_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
# ...

# %%
markex=[".",",","v","<","^",">","o","1","2","3","4","8","s","P","p","*","h","H","x","X","+","D","d","|","_"]
colox=["b","g","k","r","m","y","c","b","g","k","r","m","y","c","b","g","k","r","m","y","c","k","b","g","y"]
i=1
ax1=SuperD_P[1].plot(kind="scatter",x="Time (days)", y='a262', color='r',figsize=(6,6))
plt.title("Placebo effect on Tumor Growth")
bx1=SuperD_C[1].plot(kind="scatter",x="Time (days)", y='b128', color='r',figsize=(6,6))
plt.title("Capomulin effect on Tumor Growth")
for valuex in range(2,len(SuperD_P[1].columns)):
    SuperD_P[1].plot(kind="scatter",x=SuperD_P[1].columns[0], y=valuex, color=colox[i],marker=markex[i],ax=ax1)
    SuperD_C[1].plot(kind="scatter",x=SuperD_C[1].columns[0], y=valuex, color=colox[i],marker=markex[i],ax=bx1)
    i=i+1 
bx1.set_ylabel("Tumor Volume (mm3)")
ax1.set_ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %% [markdown]
# # CAPOMULIN EFFECT ON TUMOR GROWTH

# %%
SuperD_C[2]
# Out:
# <style  type="text/css" >
#     #T_37ccbe9e_c124_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #138a13;
#             color:  #000000;
#         }    #T_37ccbe9e_c124_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_37ccbe9e_c124_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_37ccbe9e_c124_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #3ea23e;
#             color:  #000000;
#         }    #T_37ccbe9e_c124_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_37ccbe9e_c124_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #0d870d;
#             color:  #f1f1f1;
#         }    #T_37ccbe9e_c124_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #48a848;
#             color:  #000000;
# ...

# %% [markdown]
# # KETAPRIL EFFECT ON TUMOR GROWTH

# %%
SuperD_K[2]
# Out:
# <style  type="text/css" >
#     #T_38764c52_c124_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_38764c52_c124_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_38764c52_c124_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_38764c52_c124_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_38764c52_c124_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_38764c52_c124_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_38764c52_c124_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
# ...

# %%
i=1
cx1=SuperD_K[1].plot(kind="scatter",x="Time (days)", y='a457', color='r',figsize=(6,6))
plt.title("Ketapril effect on Tumor Growth")
dx1=SuperD_I[1].plot(kind="scatter",x="Time (days)", y='z581', color='r',figsize=(6,6)) 
plt.title("Infubinol effect on Tumor Growth")
for valuex in range(2,len(SuperD_K[1].columns)):
    SuperD_K[1].plot(kind="scatter",x=SuperD_K[1].columns[0], y=valuex, color=colox[i],marker=markex[i],ax=cx1)
    SuperD_I[1].plot(kind="scatter",x=SuperD_I[1].columns[0], y=valuex, color=colox[i],marker=markex[i],ax=dx1)
    i=i+1
cx1.set_ylabel("Tumor Volume (mm3)")
dx1.set_ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %% [markdown]
# # INFUBINOL EFFECT ON TUMOR'S GROWTH

# %%
SuperD_I[2]
# Out:
# <style  type="text/css" >
#     #T_39b5a158_c124_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_39b5a158_c124_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_39b5a158_c124_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_39b5a158_c124_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_39b5a158_c124_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_39b5a158_c124_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_39b5a158_c124_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
# ...

# %%
AvT=pd.merge(SuperD_P[0],SuperD_C[0],on="Time (days)")
AvT=pd.merge(AvT,SuperD_K[0],on="Time (days)")
AvT=pd.merge(AvT,SuperD_I[0],on="Time (days)")
AvT=AvT.reset_index()
AvT
# Out:
#    Time (days)  Placebo (Alive Mice)  Placebo (Mean)  Placebo (StdE)  \
# 0            0                  25.0       45.000000        0.000000
# 1            5                  24.0       47.125589        0.213684
# 2           10                  24.0       49.423329        0.393940
# 3           15                  20.0       51.359742        0.549591
# 4           20                  19.0       54.364417        0.731954
# 5           25                  17.0       57.482574        0.853377
# 6           30                  15.0       59.809063        0.943638
# 7           35                  14.0       62.420615        0.963462
# 8           40                  12.0       65.052675        0.949603
# 9           45                  11.0       68.084082        0.896633
#
#    Capomulin (Alive Mice)  Capomulin (Mean)  Capomulin (StdE)  \
# 0                    25.0         45.000000          0.000000
# 1                    25.0         44.266086          0.448593
# ...

# %%
gl=AvT.plot(x="Time (days)", y="Placebo (Mean)",linestyle="-.", color='r',marker="8",figsize=(6,6))
AvT.plot(x="Time (days)", y="Capomulin (Mean)",linestyle="--", color='b',marker="^",ax=gl)
AvT.plot(x="Time (days)", y="Ketapril (Mean)", color='k',marker="s",ax=gl)
AvT.plot(x="Time (days)", y="Infubinol (Mean)", color='m',marker="4",ax=gl)
plt.ylabel("Tumor Volume (mm3)")
plt.title("Treatment effect on Tumor Growth")
# Out:
# Text(0.5, 1.0, 'Treatment effect on Tumor Growth')

# %%
#plt.style.use('seaborn-whitegrid')

x_data=AvT["Time (days)"].tolist()
y_data=AvT["Placebo (Mean)"].tolist()
yerr=AvT["Placebo (StdE)"].tolist()

y_data1=AvT["Capomulin (Mean)"].tolist()
yerr1=AvT["Capomulin (StdE)"].tolist()

y_data2=AvT["Ketapril (Mean)"].tolist()
yerr2=AvT["Ketapril (StdE)"].tolist()

y_data3=AvT["Infubinol (Mean)"].tolist()
yerr3=AvT["Infubinol (StdE)"].tolist()

ax=plt.subplot()
plt.rcParams["figure.figsize"] = (8,10)
plt.errorbar(x_data,y_data, yerr,fmt=".k",color="k")
plt.errorbar(x_data,y_data1, yerr1,fmt="--o",color="red")
plt.errorbar(x_data,y_data2, yerr2,fmt="o",color="y")
plt.errorbar(x_data,y_data3, yerr3,fmt="o",color="g")
ax.set_title("Standard Errors")
# Out:
# Text(0.5, 1.0, 'Standard Errors')

# %% [markdown]
# # PLACEBO EFFECT ON METASTASIS

# %%
SuperD_mP[2]
# Out:
# <style  type="text/css" >
#     #T_3c1b49de_c124_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_3c1b49de_c124_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_3c1b49de_c124_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_3c1b49de_c124_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_3c1b49de_c124_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_3c1b49de_c124_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_3c1b49de_c124_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
# ...

# %% [markdown]
# # CAPOMULIN EFFECT ON METASTASIS

# %%
SuperD_mC[2]
# Out:
# <style  type="text/css" >
#     #T_3cd3d594_c124_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_3cd3d594_c124_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_3cd3d594_c124_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_3cd3d594_c124_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_3cd3d594_c124_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_3cd3d594_c124_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_3cd3d594_c124_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
# ...

# %% [markdown]
# # KETAPRIL EFFECT ON METASTASIS

# %%
SuperD_mK[2]
# Out:
# <style  type="text/css" >
#     #T_3d52a55e_c124_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3d52a55e_c124_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3d52a55e_c124_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3d52a55e_c124_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3d52a55e_c124_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3d52a55e_c124_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3d52a55e_c124_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
# ...

# %% [markdown]
# # INFUBINOL EFFECT ON METASTASIS

# %%
SuperD_mI[2]
# Out:
# <style  type="text/css" >
#     #T_3de46e3a_c124_11e9_9a91_6030d4619be4row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_3de46e3a_c124_11e9_9a91_6030d4619be4row0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_3de46e3a_c124_11e9_9a91_6030d4619be4row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_3de46e3a_c124_11e9_9a91_6030d4619be4row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_3de46e3a_c124_11e9_9a91_6030d4619be4row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_3de46e3a_c124_11e9_9a91_6030d4619be4row0_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_3de46e3a_c124_11e9_9a91_6030d4619be4row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
# ...

# %%
AvmT=pd.merge(SuperD_mP[0],SuperD_mC[0],on="Time (days)")
AvmT=pd.merge(AvmT,SuperD_mK[0],on="Time (days)")
AvmT=pd.merge(AvmT,SuperD_mI[0],on="Time (days)")
AvmT=AvmT.reset_index()
AvmT
# Out:
#    Time (days)  Placebo (Alive Mice)  Placebo (Mean)  Placebo (StdE)  \
# 0            0                  25.0        0.000000        0.000000
# 1            5                  24.0        0.375000        0.098907
# 2           10                  24.0        0.833333        0.112932
# 3           15                  20.0        1.250000        0.170139
# 4           20                  19.0        1.526316        0.204053
# 5           25                  17.0        1.941176        0.217607
# 6           30                  15.0        2.266667        0.232584
# 7           35                  14.0        2.642857        0.255489
# 8           40                  12.0        3.166667        0.205971
# 9           45                  11.0        3.272727        0.201810
#
#    Capomulin (Alive Mice)  Capomulin (Mean)  Capomulin (StdE)  \
# 0                    25.0          0.000000          0.000000
# 1                    25.0          0.160000          0.074833
# ...

# %%
fl=AvmT.plot(x="Time (days)", y="Placebo (Mean)",linestyle="-.", color='r',marker="8",figsize=(6,6))
AvmT.plot(x="Time (days)", y="Capomulin (Mean)",linestyle="--", color='b',marker="^",ax=fl)
AvmT.plot(x="Time (days)", y="Ketapril (Mean)", color='k',marker="s",ax=fl)
AvmT.plot(x="Time (days)", y="Infubinol (Mean)", color='m',marker="4",ax=fl)
plt.ylabel("Metastatic Sites")
plt.title("Treatment effect on Metastasis")
# Out:
# Text(0.5, 1.0, 'Treatment effect on Metastasis')

# %%
hl=AvmT.plot(x="Time (days)", y="Placebo (Alive Mice)",linestyle="-.", color='r',marker="8",figsize=(6,6))
AvmT.plot(x="Time (days)", y="Capomulin (Alive Mice)",linestyle="--", color='b',marker="^",ax=hl)
AvmT.plot(x="Time (days)", y="Ketapril (Alive Mice)",linestyle="-" ,color='k',marker="s",ax=hl)
AvmT.plot(x="Time (days)", y="Infubinol (Alive Mice)", color='m',marker="4",ax=hl)
plt.ylabel("Alive Mice")
plt.title("Mortality")
# Out:
# Text(0.5, 1.0, 'Mortality')

# %%
superT[superT.Timepoint==45].count()
# Out:
# Mouse_ID              130
# Timepoint             130
# Tumor Volume (mm3)    130
# Metastatic Sites      130
# Drug                  130
# dtype: int64

# %%
AvR=AvT.drop(columns=["Time (days)","Placebo (Alive Mice)","Placebo (StdE)","Capomulin (Alive Mice)",
                               "Capomulin (StdE)","Ketapril (Alive Mice)","Ketapril (StdE)","Infubinol (Alive Mice)",
                               "Infubinol (StdE)"])
AvR.reset_index()
AvRM=AvR.drop([1,2,3,4,5,6,7,8]).T
AvRM["Tumor Size Ch"]=(AvRM[9]-AvRM[0])*100/AvRM[0]
AvF=AvRM.reset_index()
AvF=AvF.reset_index()
AvF
# Out:
#    level_0             index     0          9  Tumor Size Ch
# 0        0    Placebo (Mean)  45.0  68.084082      51.297960
# 1        1  Capomulin (Mean)  45.0  36.236114     -19.475303
# 2        2   Ketapril (Mean)  45.0  70.662958      57.028795
# 3        3  Infubinol (Mean)  45.0  65.755562      46.123472

# %%
heights=AvRM["Tumor Size Ch"].tolist()
bars=AvF["index"].tolist()
bars
# Out:
# ['Placebo (Mean)', 'Capomulin (Mean)', 'Ketapril (Mean)', 'Infubinol (Mean)']

# %%
y_pos = np.arange(len(bars))
plt.bar(y_pos, heights)
# Out:
# <BarContainer object of 4 artists>
